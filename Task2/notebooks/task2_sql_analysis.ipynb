# %%
# !pip install pandas sqlalchemy
# Out:
# Requirement already satisfied: pandas in c:\users\vbhav\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: sqlalchemy in c:\users\vbhav\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vbhav\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vbhav\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vbhav\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vbhav\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\vbhav\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\vbhav\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\vbhav\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import pandas as pd
from sqlalchemy import create_engine

print("Success")
# Out:
# Success

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(r"sqlite:///C:/Users/vbhav/sales.db")

query = """
SELECT "Product Name",
       SUM(Sales) AS Total_Sales
FROM train_data
GROUP BY "Product Name"
ORDER BY Total_Sales DESC
LIMIT 5
"""

df = pd.read_sql(query, engine)

df
# Out:
#                                         Product Name  Total_Sales
# 0              Canon imageCLASS 2200 Advanced Copier    61599.824
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...    27453.384
# 2  Cisco TelePresence System EX90 Videoconferenci...    22638.480
# 3       HON 5400 Series Task Chairs for Big and Tall    21870.576
# 4         GBC DocuBind TL300 Electric Binding System    19823.479

# %%
df.to_csv("top_products.csv", index=False)

print("File exported successfully")
# Out:
# File exported successfully

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\vbhav
